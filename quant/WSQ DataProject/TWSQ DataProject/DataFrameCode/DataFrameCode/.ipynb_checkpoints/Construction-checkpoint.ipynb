# %% [markdown]
# # Pandas DataFrame: A Dictionary and Numpy 2D Array Had a Baby
# A DataFrame is a 2D spreadsheet where each column is a Series

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## DataFrame Construction

# %%
# 2D list or NumPy array

index=['20201201','20201202','20201203','20201204']
columns = ['AAPL','MSFT','TSLA','LULU']

data=[[-0.01,0.03,0.05,0.005],
      [0.015,0.005,-0.05,-0.0025],
      [-0.025,0.0015,-0.02,0.01],
      [-0.03,0.015,0.03,0.01]]

df=pd.DataFrame(data,index=index,columns=columns)
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050 -0.05 -0.0025
# 20201203 -0.025  0.0015 -0.02  0.0100
# 20201204 -0.030  0.0150  0.03  0.0100

# %%
# Dict of equal length lists or NumPy arrays

data = {'AAPL':[-0.01,0.015,-0.025,-0.03],
        'MSFT':[0.03,0.005,0.0015,0.015],
        'TSLA':[0.05,-0.05,-0.2,0.03],
        'LULU':[0.005,-0.0025,0.01,0.01]
       }

index=['20201201','20201202','20201203','20201204']
df=pd.DataFrame(data,index=index)
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050 -0.05 -0.0025
# 20201203 -0.025  0.0015 -0.20  0.0100
# 20201204 -0.030  0.0150  0.03  0.0100

# %%
# Dict of Series
index=['20201201','20201202','20201203','20201204']

data={}
data['AAPL'] = pd.Series([-0.01,0.015,-0.025,-0.03],index=index)
data['MSFT'] = pd.Series([0.03,0.005,0.0015,0.015],index=index)
data['TSLA'] = pd.Series([0.05,-0.05,-0.2,0.03],index=index)
data['LULU'] = pd.Series([0.005,-0.0025,0.01,0.01],index=index)

df=pd.DataFrame(data)
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050 -0.05 -0.0025
# 20201203 -0.025  0.0015 -0.20  0.0100
# 20201204 -0.030  0.0150  0.03  0.0100

# %% [markdown]
# ### There are many other ways to make a DataFrame:
#
# ![Screen%20Shot%202021-10-14%20at%207.19.47%20AM.png](attachment:Screen%20Shot%202021-10-14%20at%207.19.47%20AM.png)

# %% [markdown]
# ## DataFrame Deconstruction

# %%
# get data
df.values
# Out:
# array([[-0.01  ,  0.03  ,  0.05  ,  0.005 ],
#        [ 0.015 ,  0.005 , -0.05  , -0.0025],
#        [-0.025 ,  0.0015, -0.02  ,  0.01  ],
#        [-0.03  ,  0.015 ,  0.03  ,  0.01  ]])

# %%
# get columns
df.columns
# Out:
# Index(['AAPL', 'MSFT', 'TSLA', 'LULU'], dtype='object')

# %%
# get rows
df.index
# Out:
# Index(['20201201', '20201202', '20201203', '20201204'], dtype='object')

# %% [markdown]
# ## DataFrame Value Retrieval

# %%
# Grab a column > returns a Series
df['AAPL']
# Out:
# 20201201   -0.010
# 20201202    0.015
# 20201203   -0.025
# 20201204   -0.030
# Name: AAPL, dtype: float64

# %%
# Grab a row > returns a Series
df.loc['20201201']
# Out:
# AAPL   -0.010
# MSFT    0.030
# TSLA    0.050
# LULU    0.005
# Name: 20201201, dtype: float64

# %%
# grab TSLA price on 20201203
print (df['TSLA']['20201203'])
print (df.loc['20201203']['TSLA'])
# Out:
# -0.2
# -0.2

# %%
# better way to grab TSLA price on 20201203
df.loc['20201203','TSLA']
# Out:
# -0.2

# %%
# subset the dataframe using loc 
df.loc[['20201201','20201203'],['TSLA','AAPL']]
# Out:
#           TSLA  AAPL
# 20201201  0.05   0.0
# 20201203  0.00   0.0

# %%
df.loc[df['TSLA']>0,['TSLA','AAPL']]
# Out:
#           TSLA  AAPL
# 20201201  0.05   0.0
# 20201204  0.03   0.0

# %%
# most of the retrieval methods for series work here too 
df.loc['20201201':'20201203']
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050 -0.05 -0.0025
# 20201203 -0.025  0.0015 -0.20  0.0100

# %%
df[df['AAPL']<0]
# Out:
#            AAPL    MSFT  TSLA   LULU
# 20201201 -0.010  0.0300  0.05  0.005
# 20201203 -0.025  0.0015 -0.20  0.010
# 20201204 -0.030  0.0150  0.03  0.010

# %%
df[df<0]
# Out:
#            AAPL  MSFT  TSLA    LULU
# 20201201 -0.010   NaN   NaN     NaN
# 20201202    NaN   NaN -0.05 -0.0025
# 20201203 -0.025   NaN -0.20     NaN
# 20201204 -0.030   NaN   NaN     NaN

# %% [markdown]
# ## DataFrame Value Modification

# %%
# set entire column to scaler
df['TSLA']=0
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300     0  0.0050
# 20201202  0.015  0.0050     0 -0.0025
# 20201203 -0.025  0.0015     0  0.0100
# 20201204 -0.030  0.0150     0  0.0100

# %%
# set column using list
df['TSLA']=[0.05,-0.05,-0.2,0.03]
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050 -0.05 -0.0025
# 20201203 -0.025  0.0015 -0.20  0.0100
# 20201204 -0.030  0.0150  0.03  0.0100

# %%
# set column using series
tsla = pd.Series({'20201204':0.01,'20201201':0.02,'20201202':0.04})
tsla
# Out:
# 20201204    0.01
# 20201201    0.02
# 20201202    0.04
# dtype: float64

# %%
df['TSLA']=tsla
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.02  0.0050
# 20201202  0.015  0.0050  0.04 -0.0025
# 20201203 -0.025  0.0015   NaN  0.0100
# 20201204 -0.030  0.0150  0.01  0.0100

# %%
# new column
df['XOM']=[0.01,0.005,-0.005,0.025]
df
# Out:
#            AAPL    MSFT  TSLA    LULU    XOM
# 20201201 -0.010  0.0300  0.02  0.0050  0.010
# 20201202  0.015  0.0050  0.04 -0.0025  0.005
# 20201203 -0.025  0.0015   NaN  0.0100 -0.005
# 20201204 -0.030  0.0150  0.01  0.0100  0.025

# %%
# change an entry
df.loc['20201203','TSLA']=0.03
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.01  0.0050
# 20201202  0.015  0.0050  0.02 -0.0025
# 20201203 -0.025  0.0015  0.03  0.0100
# 20201204 -0.030  0.0150  0.04  0.0100

# %%
# filtering
df[df<0]=0
df
# Out:
#            AAPL    MSFT  TSLA   LULU
# 20201201  0.000  0.0300  0.05  0.005
# 20201202  0.015  0.0050  0.00  0.000
# 20201203  0.000  0.0015  0.00  0.010
# 20201204  0.000  0.0150  0.03  0.010

# %% [markdown]
# ## DataFrames Simplify Descriptive Stats with Built-In Methods
# (somehow break this down into reduction methods + arithmetic manipulations + methods like rank/cumsum)

# %%
# Subtract Market Returns
mkt_ret=0.005
df - mkt_ret
# Out:
#            AAPL    MSFT   TSLA    LULU
# 20201201 -0.015  0.0250  0.045  0.0000
# 20201202  0.010  0.0000 -0.055 -0.0075
# 20201203 -0.030 -0.0035 -0.025  0.0050
# 20201204 -0.035  0.0100  0.025  0.0050

# %%
# Many NumPy functions work "intuitively"
np.abs(df)
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201  0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050  0.05  0.0025
# 20201203  0.025  0.0015  0.02  0.0100
# 20201204  0.030  0.0150  0.03  0.0100

# %%
df.abs()
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201  0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050  0.05  0.0025
# 20201203  0.025  0.0015  0.02  0.0100
# 20201204  0.030  0.0150  0.03  0.0100

# %%
def thresh(x):
    if np.abs(x) > 0.005:
        return x
    else:
        return 0

df.applymap(thresh)
# Out:
#            AAPL   MSFT  TSLA  LULU
# 20201201 -0.010  0.030  0.05  0.00
# 20201202  0.015  0.000 -0.05  0.00
# 20201203 -0.025  0.000 -0.02  0.01
# 20201204 -0.030  0.015  0.03  0.01

# %%
df.rank()
# Out:
#           AAPL  MSFT  TSLA  LULU
# 20201201   3.0   4.0   4.0   2.0
# 20201202   4.0   2.0   1.0   1.0
# 20201203   2.0   1.0   2.0   3.5
# 20201204   1.0   3.0   3.0   3.5

# %%
df.cumsum()
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.05  0.0050
# 20201202  0.005  0.0350  0.00  0.0025
# 20201203 -0.020  0.0365 -0.02  0.0125
# 20201204 -0.050  0.0515  0.01  0.0225

# %%
# Reduction Methods: Average Return
np.mean(df)
# Out:
# AAPL   -0.012500
# MSFT    0.012875
# TSLA    0.002500
# LULU    0.005625
# dtype: float64

# %%
# average return for each stock
df.mean()
# Out:
# AAPL   -0.012500
# MSFT    0.012875
# TSLA    0.002500
# LULU    0.005625
# dtype: float64

# %%
# average return for each time
df.mean(axis=1)
# Out:
# 20201201    0.018750
# 20201202   -0.008125
# 20201203   -0.008375
# 20201204    0.006250
# dtype: float64

# %% [markdown]
# ### Do NOT do this for the average
# Whenever you find yourself writing a loop, check if there's a better way

# %%
avg={}
for x in df.index:
    tot=0
    for y in df.columns:
        tot+=df.loc[x,y]
    avg[x]=tot/df.shape[0]
avg=pd.Series(avg)
avg
# Out:
# 20201201    0.018750
# 20201202   -0.008125
# 20201203   -0.008375
# 20201204    0.006250
# dtype: float64

# %%
def max_minus_min(ser):
    return ser.max()-ser.min()
max_minus_min(df['AAPL'])
# Out:
# 0.045

# %%
df.apply(max_minus_min)
# Out:
# AAPL    0.0450
# MSFT    0.0285
# TSLA    0.1000
# LULU    0.0125
# dtype: float64

# %%
df.apply(max_minus_min,axis=1)
# Out:
# 20201201    0.060
# 20201202    0.065
# 20201203    0.035
# 20201204    0.060
# dtype: float64

# %%
def min_and_max(ser):
    return pd.Series([ser.min(),ser.max()],index=['min','max'])
df.apply(min_and_max)
# Out:
#       AAPL    MSFT  TSLA    LULU
# min -0.030  0.0015 -0.05 -0.0025
# max  0.015  0.0300  0.05  0.0100

# %%
# Describe function
df.describe()
# Out:
#            AAPL      MSFT      TSLA      LULU
# count  4.000000  4.000000  4.000000  4.000000
# mean  -0.012500  0.012875  0.002500  0.005625
# std    0.020207  0.012770  0.045735  0.005907
# min   -0.030000  0.001500 -0.050000 -0.002500
# 25%   -0.026250  0.004125 -0.027500  0.003125
# 50%   -0.017500  0.010000  0.005000  0.007500
# 75%   -0.003750  0.018750  0.035000  0.010000
# max    0.015000  0.030000  0.050000  0.010000

# %% [markdown]
# ### There are tons of functions on DataFrames. Here are some more:
# (checkout the ocumentation for the rest: https://pandas.pydata.org/docs/reference/frame.html)
# ![Screen%20Shot%202021-10-14%20at%207.37.27%20AM.png](attachment:Screen%20Shot%202021-10-14%20at%207.37.27%20AM.png)

# %%
# Correlation
df.corr()
# Out:
#           AAPL      MSFT      TSLA      LULU
# AAPL  1.000000 -0.088811 -0.550041 -0.994808
# MSFT -0.088811  1.000000  0.879688  0.056617
# TSLA -0.550041  0.879688  1.000000  0.516655
# LULU -0.994808  0.056617  0.516655  1.000000

# %%
# Covariance
df.cov()
# Out:
#           AAPL      MSFT      TSLA      LULU
# AAPL  0.000408 -0.000023 -0.000508 -0.000119
# MSFT -0.000023  0.000163  0.000514  0.000004
# TSLA -0.000508  0.000514  0.002092  0.000140
# LULU -0.000119  0.000004  0.000140  0.000035

# %%
mkt_ret = pd.Series([0.01,0.02,0.03,0.04],index=['20201201','20201202','20201203','20201204'])
df.corrwith(mkt_ret)
# Out:
# AAPL   -0.638877
# MSFT   -0.490331
# TSLA   -0.084684
# LULU    0.600994
# dtype: float64

# %% [markdown]
# ## Arithmetic Alignment

# %%
# 2D list or NumPy array

index=['20201201','20201202','20201203']
columns = ['AAPL','MSFT']

data = [[-0.005,0.01],
        [-0.025,0.0075],
        [-0.005,0.015]]
ret2=pd.DataFrame(data,index=index,columns=columns)
ret2
# Out:
#            AAPL    MSFT
# 20201201 -0.005  0.0100
# 20201202 -0.025  0.0075
# 20201203 -0.005  0.0150

# %%
df+ret2
# Out:
#            AAPL  LULU    MSFT  TSLA
# 20201201 -0.015   NaN  0.0400   NaN
# 20201202 -0.010   NaN  0.0125   NaN
# 20201203 -0.030   NaN  0.0165   NaN
# 20201204    NaN   NaN     NaN   NaN

# %%
mkt_ret=0.01
df.add(ret2,fill_value=mkt_ret)
# Out:
#            AAPL    LULU    MSFT  TSLA
# 20201201 -0.015  0.0150  0.0400  0.06
# 20201202 -0.010  0.0075  0.0125 -0.04
# 20201203 -0.030  0.0200  0.0165 -0.01
# 20201204 -0.020  0.0200  0.0250  0.04

# %% [markdown]
# ### Operations b/w a Series and DataFrame are well-defined

# %%
df
# Out:
#            AAPL    MSFT  TSLA    LULU
# 20201201 -0.010  0.0300  0.05  0.0050
# 20201202  0.015  0.0050 -0.05 -0.0025
# 20201203 -0.025  0.0015 -0.02  0.0100
# 20201204 -0.030  0.0150  0.03  0.0100

# %%
# By default arithmetic matches the index of the series on the dataframe's columns
ser = pd.Series({'AAPL':100,'MSFT':200,'TSLA':50})
df*ser
# Out:
#           AAPL  LULU  MSFT  TSLA
# 20201201  -1.0   NaN   6.0   2.5
# 20201202   1.5   NaN   1.0  -2.5
# 20201203  -2.5   NaN   0.3  -1.0
# 20201204  -3.0   NaN   3.0   1.5

# %%
ser = pd.Series({'20201201':100,'20201203':200})
df.mul(ser,axis=0)
# Out:
#           AAPL  MSFT  TSLA  LULU
# 20201201  -1.0   3.0   5.0   0.5
# 20201202   NaN   NaN   NaN   NaN
# 20201203  -5.0   0.3  -4.0   2.0
# 20201204   NaN   NaN   NaN   NaN

# %% [markdown]
# ## Putting it All Together
# Compute the return to a long/short reversal portfolio. It goes long stocks with low prior day return and short stocks with high prior day return

# %%
port=np.sign(df)/4
port
# Out:
#           AAPL  MSFT  TSLA  LULU
# 20201201 -0.25  0.25  0.25  0.25
# 20201202  0.25  0.25 -0.25 -0.25
# 20201203 -0.25  0.25 -0.25  0.25
# 20201204 -0.25  0.25  0.25  0.25

# %%
(port.shift()*df).sum(1)
# Out:
# 20201201    0.000000
# 20201202   -0.015625
# 20201203   -0.003375
# 20201204    0.006250
# dtype: float64
