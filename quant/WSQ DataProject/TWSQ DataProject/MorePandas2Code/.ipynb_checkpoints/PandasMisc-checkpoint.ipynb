# %% [markdown]
# # PDB - Debugging Tool

# %%
for x in ['AAPL','GS']:
    
    if x == 'AAPL':
        sector = 'Tech'
        tick_sz = len(x)
    
    elif x == 'GS':
        sector = 'Fin'
        tick_sz = len(x)
    
    import pdb
    pdb.set_trace()
    
    
    # do something
