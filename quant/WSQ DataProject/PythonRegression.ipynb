# %% [markdown]
# # Regression Using StatsModels
# - Run a regression to find beta and alpha of FB to SPY
# - FB<sub>t</sub> ~ $\beta$ * SPY<sub>t</sub> + $\alpha$ + e<sub>t</sub>

# %%
import statsmodels.api as sm
import pandas as pd
import numpy as np
import yfinance as yf 

# pip install yfinance
# https://pypi.org/project/yfinance/

# %%
# !pip install statsmodels
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting statsmodels
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x76052a2621a0>: Failed to establish a new connection: [Errno 101] Network is unreachable')': /packages/9f/06/2f1d2ba024c802e812fe9e85eebc06871d76f1f4e0bb2beb0faa22cbe330/statsmodels-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
#   Downloading statsmodels-0.14.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 877.9 kB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: packaging>=21.3 in /home/user/.local/lib/python3.10/site-packages (from statsmodels) (23.2)
# Collecting patsy>=0.5.6
#   Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.9/233.9 KB 1.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in /home/user/.local/lib/python3.10/site-packages (from statsmodels) (2.1.1)
# Requirement already satisfied: numpy>=1.22.3 in /home/user/.local/lib/python3.10/site-packages (from statsmodels) (1.26.0)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /home/user/.local/lib/python3.10/site-packages (from statsmodels) (1.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/user/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/user/.local/lib/python3.10/site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2024.1)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from patsy>=0.5.6->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.6 statsmodels-0.14.2

# %%
# download price data
univ = ['SPY','META']
px = yf.download(univ, start="2016-01-01")['Adj Close']
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
px
# Out:
# Ticker            META         SPY
# Date
# 2016-01-04  102.010376  173.483521
# 2016-01-05  102.519333  173.776932
# 2016-01-06  102.758835  171.584915
# 2016-01-07   97.719193  167.468323
# 2016-01-08   97.130409  165.630112
# ...                ...         ...
# 2024-07-31  474.829987  550.809998
# 2024-08-01  497.739990  543.010010
# 2024-08-02  488.140015  532.900024
# 2024-08-05  475.730011  517.380005
# 2024-08-06  498.595001  525.815125
#
# [2162 rows x 2 columns]

# %%
# get returns
ret = px / px.shift() - 1
ret
# Out:
# Ticker          META       SPY
# Date
# 2016-01-04       NaN       NaN
# 2016-01-05  0.004989  0.001691
# 2016-01-06  0.002336 -0.012614
# 2016-01-07 -0.049043 -0.023992
# 2016-01-08 -0.006025 -0.010976
# ...              ...       ...
# 2024-07-31  0.025130  0.016255
# 2024-08-01  0.048249 -0.014161
# 2024-08-02 -0.019287 -0.018618
# 2024-08-05 -0.025423 -0.029124
# 2024-08-06  0.048063  0.016304
#
# [2162 rows x 2 columns]

# %%
# set X and Y. Have to add constant
X = ret[['SPY']]
print(X)
X = sm.add_constant(X)
print(X)
Y = ret['META']
# Out:
# Ticker           SPY
# Date
# 2016-01-04       NaN
# 2016-01-05  0.001691
# 2016-01-06 -0.012614
# 2016-01-07 -0.023992
# 2016-01-08 -0.010976
# ...              ...
# 2024-07-31  0.016255
# 2024-08-01 -0.014161
# 2024-08-02 -0.018618
# 2024-08-05 -0.029124
# 2024-08-06  0.016304
#
# [2162 rows x 1 columns]
# Date
# 2016-01-04         NaN
# 2016-01-05    0.001691
# 2016-01-06   -0.012614
# 2016-01-07   -0.023992
# 2016-01-08   -0.010976
#                 ...
# 2024-07-31    0.016255
# 2024-08-01   -0.014161
# 2024-08-02   -0.018618
# 2024-08-05   -0.029124
# 2024-08-06    0.016304
# Name: SPY, Length: 2162, dtype: float64

# %%
# observe x,y
print (X)
print (Y)

# %%
# can't do this - missing data
results = sm.OLS(Y, X).fit()

# %%
# drop data
X = X.dropna()
Y = Y.dropna()
results = sm.OLS(Y, X).fit()

# %%
# check summary
results.summary()

# %%
# get params
results.params

# %%
# get tvalues
results.tvalues

# %% [markdown]
# Reconstruct FB
# - FB<sub>t</sub> ~ $\beta$ * SPY<sub>t</sub> + $\alpha$ + e<sub>t</sub>

# %%
FB = results.params['SPY']*X['SPY'] + results.params['const'] + results.resid

# %%
# basically identical
(FB-Y).abs().sum()

# %%
beta_contr = results.params['SPY']*X['SPY']
prediction = results.params['SPY']*X['SPY'] + results.params['const']
alpha_contr = results.params['const'] + results.resid

# %%
alpha_contr

# %%
alpha_contr.cumsum().plot()

# %%
# correl is zero to spy
alpha_contr.corr(X['SPY'])

# %%
# "alpha"
alpha_contr.mean()

# %%
# information ratio
alpha_contr.mean()/alpha_contr.std()*np.sqrt(252)

# %%
# alpha t-stat
results.tvalues['const']
