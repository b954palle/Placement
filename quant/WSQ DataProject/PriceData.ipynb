# %% [markdown]
# # Yahoo Finance: Daily Price Bars
# 1. Install yfinance: pip install yfinance
# 2. Documentation: https://pypi.org/project/yfinance/
# 3. GitHub: https://github.com/ranaroussi/yfinance

# %%
import yfinance as yf
import pandas as pd

# %%
univ = ['AAPL','MSFT','GOOG','AMZN','META','TSLA','BRK-A','NVDA','V']
stock_px = yf.download(univ, start="2019-01-01")
# Out:
# [*********************100%%**********************]  9 of 9 completed

# %%
stock_px
# Out:
# Price        Adj Close                                                \
# Ticker            AAPL        AMZN     BRK-A        GOOG        META
# Date
# 2019-01-02   37.793785   76.956497  304057.0   52.233059  135.401764
# 2019-01-03   34.029240   75.014000  287000.0   50.745255  131.469833
# 2019-01-04   35.481915   78.769501  292500.0   53.474648  137.667099
# 2019-01-07   35.402950   81.475502  295400.0   53.358780  137.766907
# 2019-01-08   36.077835   82.829002  294300.0   53.752831  142.237717
# ...                ...         ...       ...         ...         ...
# 2024-07-29  218.240005  183.199997  658060.0  171.130005  465.709991
# 2024-07-30  218.800003  181.710007  662125.0  171.860001  463.190002
# 2024-07-31  222.080002  186.979996  659211.0  173.149994  474.829987
# 2024-08-01  218.360001  184.070007  647000.0  172.449997  497.739990
# 2024-08-02  219.860001  167.899994  641435.0  168.399994  488.140015
#
# Price                                                            Close  ...  \
# Ticker            MSFT        NVDA        TSLA           V        AAPL  ...
# Date                                                                    ...
# 2019-01-02   95.673454    3.378611   20.674667  127.987572   39.480000  ...
# 2019-01-03   92.153801    3.174486   20.024000  123.375351   35.547501  ...
# 2019-01-04   96.439819    3.377868   21.179333  128.690460   37.064999  ...
# 2019-01-07   96.562836    3.556694   22.330667  131.011032   36.982498  ...
# 2019-01-08   97.262978    3.468149   22.356667  131.723602   37.687500  ...
# ...                ...         ...         ...         ...         ...  ...
# 2024-07-29  426.730011  111.589996  232.100006  261.600006  218.240005  ...
# 2024-07-30  422.920013  103.730003  222.619995  263.100006  218.800003  ...
# 2024-07-31  418.350006  117.019997  232.070007  265.670013  222.080002  ...
# 2024-08-01  417.109985  109.209999  216.860001  265.929993  218.360001  ...
# 2024-08-02  408.489990  107.269997  207.669998  266.579987  219.860001  ...
#
# Price             Open     Volume                                       \
# Ticker               V       AAPL       AMZN BRK-A      GOOG      META
# Date
# 2019-01-02  130.000000  148158800  159662000   400  30652000  28146200
# 2019-01-03  131.210007  365248800  139512000   700  36822000  22717900
# 2019-01-04  130.440002  234428400  183652000   800  41878000  29002100
# 2019-01-07  134.449997  219111200  159864000   600  39638000  20089300
# 2019-01-08  137.970001  164101200  177628000   300  35298000  26263800
# ...                ...        ...        ...   ...       ...       ...
# 2024-07-29  260.320007   36311800   33270100  2000  13768900  11339600
# 2024-07-30  263.230011   41643800   39508600  1600  13681400  11390400
# 2024-07-31  264.540009   50036300   41667300  1500  15650200  24285800
# 2024-08-01  266.329987   62501000   70435600  1900  17177800  43083100
# 2024-08-02  263.829987   98480100  141276100  1800  18888000  24019800
#
# Price
# Ticker          MSFT       NVDA       TSLA         V
# Date
# 2019-01-02  35329300  508752000  174879000   8788000
# 2019-01-03  42579100  705552000  104478000   9428300
# 2019-01-04  44060600  585620000  110911500  11065800
# 2019-01-07  35656100  709160000  113268000  12928000
# 2019-01-08  31514400  786016000  105127500   9243000
# ...              ...        ...        ...       ...
# 2024-07-29  15125800  248152100  129201800   6068100
# 2024-07-30  32687600  486833300  100560300   5941800
# 2024-07-31  42891400  473174200   67497000   7642500
# 2024-08-01  30296400  523462300   83861900   7269700
# 2024-08-02  29399700  480242500   82552200   7016800
#
# [1406 rows x 54 columns]

# %%
stock_px['Adj Close']['AAPL'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
min_data = yf.download(tickers="AAPL", interval="1wk", start='2019-01-01')
min_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-01   38.722500   39.712502   35.500000   36.982498   35.402943
# 2019-01-08   37.389999   38.632500   37.130001   37.500000   35.898342
# 2019-01-15   37.567501   39.470001   37.512501   39.205002   37.530521
# 2019-01-22   39.102501   39.532501   37.924999   39.075001   37.406071
# 2019-01-29   39.062500   42.915001   38.527500   42.812500   40.983948
# ...                ...         ...         ...         ...         ...
# 2024-07-02  216.149994  227.850006  215.100006  227.820007  227.820007
# 2024-07-09  227.929993  237.229996  225.770004  234.399994  234.399994
# 2024-07-16  235.000000  236.270004  222.270004  223.960007  223.960007
# 2024-07-23  224.369995  226.940002  214.619995  218.240005  218.240005
# 2024-07-30  219.190002  225.600006  216.119995  219.860001  219.860001
#
#                Volume
# Date
# 2019-01-01  966947200
# 2019-01-08  725470000
# 2019-01-15  491411200
# 2019-01-22  554774800
# 2019-01-29  830400800
# ...               ...
# 2024-07-02  214914300
# 2024-07-09  291092200
# 2024-07-16  263968100
# 2024-07-23  231042200
# 2024-07-30  350744737
#
# [292 rows x 6 columns]

# %%
min_data = yf.download(tickers="AAPL", interval="1m", period='5d')
min_data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2024-07-29 09:30:00-04:00  216.679993  217.479996  216.679993  216.679993
# 2024-07-29 09:31:00-04:00  216.684601  216.889999  215.759995  216.119995
# 2024-07-29 09:32:00-04:00  216.115005  217.199997  215.929993  217.160004
# 2024-07-29 09:33:00-04:00  217.119995  217.589996  216.529999  216.736694
# 2024-07-29 09:34:00-04:00  216.735001  217.479996  216.600006  217.089996
# ...                               ...         ...         ...         ...
# 2024-08-02 15:55:00-04:00  219.850006  219.929993  219.520004  219.669998
# 2024-08-02 15:56:00-04:00  219.660004  219.869995  219.529999  219.684998
# 2024-08-02 15:57:00-04:00  219.699997  219.839996  219.500000  219.550003
# 2024-08-02 15:58:00-04:00  219.559998  219.610001  219.059998  219.289993
# 2024-08-02 15:59:00-04:00  219.268204  219.949997  219.220001  219.800003
#
#                             Adj Close   Volume
# Datetime
# 2024-07-29 09:30:00-04:00  216.679993  1551381
# 2024-07-29 09:31:00-04:00  216.119995   605123
# 2024-07-29 09:32:00-04:00  217.160004   285186
# 2024-07-29 09:33:00-04:00  216.736694   241540
# 2024-07-29 09:34:00-04:00  217.089996   166513
# ...                               ...      ...
# 2024-08-02 15:55:00-04:00  219.669998   521594
# 2024-08-02 15:56:00-04:00  219.684998   614986
# 2024-08-02 15:57:00-04:00  219.550003   579836
# 2024-08-02 15:58:00-04:00  219.289993   884815
# 2024-08-02 15:59:00-04:00  219.800003  1599299
#
# [1943 rows x 6 columns]

# %%
# crypto daily bars
univ = ['BTC-USD','ETH-USD','BNB-USD','ADA-USD','LINK-USD','XRP-USD','XLM-USD','DOGE-USD','AVAX-USD']
crypto_px = yf.download(univ, start="2019-01-01")

# %%
crypto_px['Close']['BTC-USD'].plot()

# %%
crypto_px.to_pickle('crypto_px.pk')

# %%
pd.read_pickle('crypto_px.pk')

# %% [markdown]
# # Kraken Downloadable CSV
# https://support.kraken.com/hc/en-us/articles/360047124832-Downloadable-historical-OHLCVT-Open-High-Low-Close-Volume-Trades-data

# %% [markdown]
# # Binance API for more crypto coins and minute bar data
# 1. Install python-binance: pip install python-binance
# 2. Documentation: https://python-binance.readthedocs.io/en/latest/
# 3. GitHub: https://github.com/sammchardy/python-binance

# %%
from binance.client import Client as bnb_client
from datetime import datetime
import pandas as pd 

client = bnb_client() # if you're in the US, please use: client=bnb_client(tld='US')'
px = client.get_historical_klines('BTCUSDT','1d','2018-12-15')

# %%
px

# %%
def format_binance(data):
    columns = ['open_time','open','high','low','close','volume','close_time','quote_volume',
    'num_trades','taker_base_volume','taker_quote_volume','ignore']

    data = pd.DataFrame(data,columns = columns)
    
    # Convert from POSIX timestamp (number of millisecond since jan 1, 1970)
    data['open_time'] = data['open_time'].map(lambda x: datetime.fromtimestamp(x/1000))
    data['close_time'] = data['close_time'].map(lambda x: datetime.fromtimestamp(x/1000))
    return data

# %%
format_binance(px)

# %%
# get all the historical data
px = format_binance(client.get_historical_klines('BTCUSDT','1d',0))

# %%
px

# %%
# interval strings
client.KLINE_INTERVAL_1MINUTE

# %%
# Get minute bar data
px = client.get_historical_klines('BTCUSDT','1m','2021-10-20 23:00:00')

# %%
px = format_binance(px)
px

# %%
px.to_pickle('BINANCE_BTCUSDT_1M.pk')

# %%
pd.read_pickle('BINANCE_BTCUSDT_1M.pk')

# %% [markdown]
# # Other
# - We will add to this as class goes on (pandas datareader, ccxt, quandl, simfin)
